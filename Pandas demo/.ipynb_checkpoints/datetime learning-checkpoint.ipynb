# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df=pd.read_csv("ETH_1h.csv")

# %%
df['Date']=pd.to_datetime(df["Date"], format="%Y-%m-%d %I-%p" )

# %%
df.set_index('Date', inplace=True)

# %%
pd.set_option'display.max_columns',10)

# %%
df.loc['2020':'2021']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  Date
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93  2020
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02   117.1  129.94  7579741.09  2020
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85   115.5  119.51  4898735.81  2020
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92  2020
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71  2020
# ...                     ...     ...     ...     ...     ...         ...   ...
# 2020-01-01 04:00:00  ETHUSD  129.57   130.0   129.5  129.56   702786.82  2020
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23  2020
# 2020-01-01 02:00:00  ETHUSD  130.14   130.5  129.91  130.37   396315.72  2020
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14    635419.4  2020
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91  2020
#
# [1749 rows x 7 columns]
